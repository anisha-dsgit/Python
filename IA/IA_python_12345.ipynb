# %% [markdown]
# 1. Write a program that takes a string as input, and counts the frequency of each word in the string, there might
# be repeated characters in the string. Your task is to find the highest frequency and returns the length of the
# highest-frequency word.

# %%
# return max freq string and its length
string1 = " write write write write write all the number number from from from from from 1 to 100" 
str_list= string1.split()
def count_unique(string):
    freq_dict={}
    count=1
    for i in str_list:
        if i in freq_dict:
            continue
            freq_dict[i]=count
        else:
            count=str_list.count(i)
            freq_dict[i]=count
    
    print(freq_dict)
    
    max_val=max(list(freq_dict.values()))
    max_val_keys= []

    for key, value in freq_dict.items():
        if value == max_val :
            max_val_keys.append(key)
    
    maxlen=0
    for i in max_val_keys:
        if len(i)>maxlen:
            print(f"key having highest frequency in string is: {i}")
            maxlen=len(i)
    
    return  f"key with max len is: {maxlen}" 
    
        
count_unique(string=string1)
# Out:
# {'write': 5, 'all': 1, 'the': 1, 'number': 2, 'from': 5, '1': 1, 'to': 1, '100': 1}
# key having highest frequency in string is: write
# 'key with max len is: 5'

# %% [markdown]
# 2. Consider a string to be valid if all characters of the string appear the same number of times. It is also valid if
# he can remove just one character at the index in the string, and the remaining characters will occur the same
# number of times. Given a string, determine if it is valid. If so, return YES , otherwise return NO .

# %%
string_1 =input("Enter any sentence ")

def string_check(input_string):
    freq_dict={}
    for i in input_string:
        char_count=1
        if i in freq_dict:
            char_count+=1
            continue
        else:
            freq_dict[i]=char_count
    return freq_dict

string_check(string_1)
# Out:
# {'t': 1,
#  'o': 1,
#  'd': 1,
#  'a': 1,
#  'y': 1,
#  ' ': 1,
#  'i': 1,
#  's': 1,
#  'v': 1,
#  'e': 1,
#  'r': 1,
#  'g': 1}

# %% [markdown]
# 3. Write a program, which would download the data from the provided link, and then read the data and convert
# that into properly structured data and return it in Excel format.

# %%
import pandas as pd
import requests
import json

# %%
Link ="https://raw.githubusercontent.com/Biuni/PokemonGO-Pokedex/master/pokedex.json"

json_df=pd.read_json(Link)
json_df
# Out:
#                                                pokemon
# 0    {'id': 1, 'num': '001', 'name': 'Bulbasaur', '...
# 1    {'id': 2, 'num': '002', 'name': 'Ivysaur', 'im...
# 2    {'id': 3, 'num': '003', 'name': 'Venusaur', 'i...
# 3    {'id': 4, 'num': '004', 'name': 'Charmander', ...
# 4    {'id': 5, 'num': '005', 'name': 'Charmeleon', ...
# ..                                                 ...
# 146  {'id': 147, 'num': '147', 'name': 'Dratini', '...
# 147  {'id': 148, 'num': '148', 'name': 'Dragonair',...
# 148  {'id': 149, 'num': '149', 'name': 'Dragonite',...
# 149  {'id': 150, 'num': '150', 'name': 'Mewtwo', 'i...
# 150  {'id': 151, 'num': '151', 'name': 'Mew', 'img'...
#
# [151 rows x 1 columns]

# %%
pokemon_df=pd.json_normalize(json_df['pokemon'])
pokemon_df.head(3)
# Out:
#    id  num       name                                               img  \
# 0   1  001  Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png
# 1   2  002    Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2   3  003   Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
#
#               type  height    weight            candy  candy_count  \
# 0  [Grass, Poison]  0.71 m    6.9 kg  Bulbasaur Candy         25.0
# 1  [Grass, Poison]  0.99 m   13.0 kg  Bulbasaur Candy        100.0
# 2  [Grass, Poison]  2.01 m  100.0 kg  Bulbasaur Candy          NaN
#
#            egg  spawn_chance  avg_spawns spawn_time multipliers  \
# 0         2 km         0.690        69.0      20:00      [1.58]
# 1  Not in Eggs         0.042         4.2      07:00  [1.2, 1.6]
# 2  Not in Eggs         0.017         1.7      11:30        None
#
#                      weaknesses  \
# 0  [Fire, Ice, Flying, Psychic]
# 1  [Fire, Ice, Flying, Psychic]
# 2  [Fire, Ice, Flying, Psychic]
#
# ...

# %%
#convert to excel file 
pokemon_df.to_excel("pokemon.xlsx")

# %% [markdown]
# 4. Write a program to download the data from the link given below and then read the data and convert the into
# the proper structure and return it as a CSV file.
# Link - https://data.nasa.gov/resource/y77d-th95.json

# %%
link="https://data.nasa.gov/resource/y77d-th95.json"
pd.set_option("display.max_columns",None)
df= pd.read_json(link)
df.head(3)
# Out:
#      name  id nametype recclass      mass  fall                     year  \
# 0  Aachen   1    Valid       L5      21.0  Fell  1880-01-01T00:00:00.000
# 1  Aarhus   2    Valid       H6     720.0  Fell  1951-01-01T00:00:00.000
# 2    Abee   6    Valid      EH4  107000.0  Fell  1952-01-01T00:00:00.000
#
#      reclat    reclong                                        geolocation  \
# 0  50.77500    6.08333  {'type': 'Point', 'coordinates': [6.08333, 50....
# 1  56.18333   10.23333  {'type': 'Point', 'coordinates': [10.23333, 56...
# 2  54.21667 -113.00000  {'type': 'Point', 'coordinates': [-113, 54.216...
#
#    :@computed_region_cbhk_fwbd  :@computed_region_nnqa_25f4
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN

# %%
df.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass', 'fall', 'year', 'reclat',
#        'reclong', 'geolocation', ':@computed_region_cbhk_fwbd',
#        ':@computed_region_nnqa_25f4'],
#       dtype='object')

# %%
df=df.drop([':@computed_region_cbhk_fwbd',
       ':@computed_region_nnqa_25f4'], axis=1)

df.head()
# Out:
#        name   id nametype     recclass      mass  fall  \
# 0    Aachen    1    Valid           L5      21.0  Fell
# 1    Aarhus    2    Valid           H6     720.0  Fell
# 2      Abee    6    Valid          EH4  107000.0  Fell
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4   Achiras  370    Valid           L6     780.0  Fell
#
#                       year    reclat    reclong  \
# 0  1880-01-01T00:00:00.000  50.77500    6.08333
# 1  1951-01-01T00:00:00.000  56.18333   10.23333
# 2  1952-01-01T00:00:00.000  54.21667 -113.00000
# 3  1976-01-01T00:00:00.000  16.88333  -99.90000
# 4  1902-01-01T00:00:00.000 -33.16667  -64.95000
#
#                                          geolocation
# 0  {'type': 'Point', 'coordinates': [6.08333, 50....
# 1  {'type': 'Point', 'coordinates': [10.23333, 56...
# 2  {'type': 'Point', 'coordinates': [-113, 54.216...
# 3  {'type': 'Point', 'coordinates': [-99.9, 16.88...
# 4  {'type': 'Point', 'coordinates': [-64.95, -33....

# %%
json_location=pd.json_normalize(df['geolocation'])
point_coordinates=json_location['coordinates']
point_coordinates
# Out:
# 0          [6.08333, 50.775]
# 1       [10.23333, 56.18333]
# 2           [-113, 54.21667]
# 3          [-99.9, 16.88333]
# 4        [-64.95, -33.16667]
#                ...
# 995     [79.41667, 13.63333]
# 996     [-7.61123, 29.48195]
# 997    [111.53333, -7.08333]
# 998    [106.58333, -6.66667]
# 999        [34.76667, 47.85]
# Name: coordinates, Length: 1000, dtype: object

# %%
#converted a series of just point coordinates to another df column specifically containing list of point coordinates
df['point_coordinates']=point_coordinates

# %%
df=df.drop('geolocation',axis=1)
df.head(2)
# Out:
#      name  id nametype recclass   mass  fall                     year  \
# 0  Aachen   1    Valid       L5   21.0  Fell  1880-01-01T00:00:00.000
# 1  Aarhus   2    Valid       H6  720.0  Fell  1951-01-01T00:00:00.000
#
#      reclat   reclong     point_coordinates
# 0  50.77500   6.08333     [6.08333, 50.775]
# 1  56.18333  10.23333  [10.23333, 56.18333]

# %%
df['year']=df['year'].str[0:4]
df.head(3)
# Out:
#      name  id nametype recclass      mass  fall  year    reclat    reclong  \
# 0  Aachen   1    Valid       L5      21.0  Fell  1880  50.77500    6.08333
# 1  Aarhus   2    Valid       H6     720.0  Fell  1951  56.18333   10.23333
# 2    Abee   6    Valid      EH4  107000.0  Fell  1952  54.21667 -113.00000
#
#       point_coordinates
# 0     [6.08333, 50.775]
# 1  [10.23333, 56.18333]
# 2      [-113, 54.21667]

# %%
#trying to make the coordinates in integer format as they are currently in float format 
df['point_coordinates'][0]=[int(x) if isinstance(x, (int, float)) else x for x in df['point_coordinates'][0]]
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_32248\3081412240.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['point_coordinates'][0]=[int(x) if isinstance(x, (int, float)) else x for x in df['point_coordinates'][0]]
# 0      [<function <listcomp>.<lambda> at 0x000001A78F...
# 1                     <map object at 0x000001A78E688E80>
# 2                     <map object at 0x000001A78F044EB0>
# 3                     <map object at 0x000001A78F044BE0>
# 4                     <map object at 0x000001A78ED6FD90>
#                              ...
# 995                                 [79.41667, 13.63333]
# 996                                 [-7.61123, 29.48195]
# 997                                [111.53333, -7.08333]
# 998                                [106.58333, -6.66667]
# ...

# %% [markdown]
# 5. Write a program to download the data from the given API link and then extract the following data with
# proper formatting.
# Link - http://api.tvmaze.com/singlesearch/shows?q=westworld&embed=episodes

# %%
import json
import pandas as pd
import requests
url = "http://api.tvmaze.com/singlesearch/shows?q=westworld&embed=episodes"

response= requests.get(url=url)
json_data= response.json()
json_data
# Out:
# {'id': 1371,
#  'url': 'https://www.tvmaze.com/shows/1371/westworld',
#  'name': 'Westworld',
#  'type': 'Scripted',
#  'language': 'English',
#  'genres': ['Drama', 'Science-Fiction', 'Western'],
#  'status': 'Ended',
#  'runtime': 60,
#  'averageRuntime': 63,
#  'premiered': '2016-10-02',
#  'ended': '2022-08-14',
#  'officialSite': 'http://www.hbo.com/westworld',
#  'schedule': {'time': '21:00', 'days': ['Sunday']},
#  'rating': {'average': 8.2},
#  'weight': 99,
#  'network': {'id': 8,
#   'name': 'HBO',
#   'country': {'name': 'United States',
#    'code': 'US',
#    'timezone': 'America/New_York'},
#   'officialSite': 'https://www.hbo.com/'},
#  'webChannel': None,
#  'dvdCountry': None,
#  'externals': {'tvrage': 37537, 'thetvdb': 296762, 'imdb': 'tt0475784'},
#  'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_portrait/445/1113927.jpg',
#   'original': 'https://static.tvmaze.com/uploads/images/original_untouched/445/1113927.jpg'},
# ...

# %%
episode_data_Df=pd.json_normalize(json_data)
episode_data_Df
# Out:
#      id                                          url       name      type  \
# 0  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld  Scripted
#
#   language                             genres status  runtime  averageRuntime  \
# 0  English  [Drama, Science-Fiction, Western]  Ended       60              63
#
#     premiered       ended                  officialSite  weight webChannel  \
# 0  2016-10-02  2022-08-14  http://www.hbo.com/westworld      99       None
#
#   dvdCountry                                            summary     updated  \
# 0       None  <p><b>Westworld</b> is a dark odyssey about th...  1675592943
#
#   schedule.time schedule.days  rating.average  network.id network.name  \
# 0         21:00      [Sunday]             8.2           8          HBO
#
#   network.country.name network.country.code network.country.timezone  \
# 0        United States                   US         America/New_York
#
# ...

# %%
embedded_episodes=pd.json_normalize(episode_data_Df['_embedded.episodes'])
transposed_epi=embedded_episodes.transpose()
transposed_epi
# Out:
#                                                     0
# 0   {'id': 869671, 'url': 'https://www.tvmaze.com/...
# 1   {'id': 911201, 'url': 'https://www.tvmaze.com/...
# 2   {'id': 911204, 'url': 'https://www.tvmaze.com/...
# 3   {'id': 911205, 'url': 'https://www.tvmaze.com/...
# 4   {'id': 927174, 'url': 'https://www.tvmaze.com/...
# 5   {'id': 932057, 'url': 'https://www.tvmaze.com/...
# 6   {'id': 938404, 'url': 'https://www.tvmaze.com/...
# 7   {'id': 943065, 'url': 'https://www.tvmaze.com/...
# 8   {'id': 943066, 'url': 'https://www.tvmaze.com/...
# 9   {'id': 943067, 'url': 'https://www.tvmaze.com/...
# 10  {'id': 1214222, 'url': 'https://www.tvmaze.com...
# 11  {'id': 1440915, 'url': 'https://www.tvmaze.com...
# 12  {'id': 1440916, 'url': 'https://www.tvmaze.com...
# 13  {'id': 1440917, 'url': 'https://www.tvmaze.com...
# 14  {'id': 1446362, 'url': 'https://www.tvmaze.com...
# 15  {'id': 1453278, 'url': 'https://www.tvmaze.com...
# ...

# %%
episode_df=pd.json_normalize(transposed_epi[0])
episode_df.head(3)
# Out:
#        id                                                url          name  \
# 0  869671  https://www.tvmaze.com/episodes/869671/westwor...  The Original
# 1  911201  https://www.tvmaze.com/episodes/911201/westwor...      Chestnut
# 2  911204  https://www.tvmaze.com/episodes/911204/westwor...     The Stray
#
#    season  number     type     airdate airtime                   airstamp  \
# 0       1       1  regular  2016-10-02   21:00  2016-10-03T01:00:00+00:00
# 1       1       2  regular  2016-10-09   21:00  2016-10-10T01:00:00+00:00
# 2       1       3  regular  2016-10-16   21:00  2016-10-17T01:00:00+00:00
#
#    runtime                                            summary  rating.average  \
# 0       68  <p>A woman named Dolores is a free spirit in t...             8.0
# 1       60  <p>Bernard suspects that someone is sabotaging...             7.7
# 2       60  <p>Bernard continues to investigate Dolores' s...             7.6
#
# ...
